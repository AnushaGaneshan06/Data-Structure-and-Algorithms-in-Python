# %% [markdown]
# # Python Full Topics Overview
#
#
#
# ### 1. 🐍 Python Basics
#
# 1.1 📝 Variables & Operators
# - 📦 Variables: Declaring and assigning values
# - 🔢 Data Types: int, float, str, bool, list, tuple, dict, etc.
# - ➕ Arithmetic Operators: +, -, *, /, //, %, **
# - 🔄 Comparison Operators: ==, !=, <, >, <=, >=
# - 🧠 Logical Operators: and, or, not
# - 📝 Assignment Operators: =, +=, -=, *=, /=
# - 🔣 Bitwise Operators: &, |, ^, ~, <<, >>
#
# 1.2 🔤 Strings & Input
# - 🔗 String Operations: Concatenation, repetition, slicing, indexing
# - 🛠️ String Methods: upper(), lower(), find(), replace(), split(), join(), etc.
# - 📝 String Formatting: f-strings, format(), % formatting
# - ⌨️ Taking User Input: input() and type conversion
#
#
# ------------------------------------
#
#
#
# ### 2. 📦 Data Structures
#
# 2.1 📝 Lists
# - 🗂️ Creating lists
# - 🧮 Indexing and slicing
# - 🛠️ List Methods: append(), extend(), insert(), remove(), pop(), etc.
# - 💡 List Comprehension
#
# 2.2 📦 Tuples
# - 🗂️ Creating tuples
# - 🧮 Indexing and slicing
# - 🔒 Immutability of tuples
#
# 2.3 🧮 Sets
# - 🗂️ Creating sets
# - ➕ Adding and removing elements
# - ⚙️ Set Operations: Union, Intersection, Difference
#
# 2.4 📜 Dictionaries
# - 🗂️ Creating dictionaries
# - 🔑 Accessing items by keys
# - ➕ Adding and removing key-value pairs
# - 🔄 Looping through keys and values
# - 💡 Dictionary comprehension
#
#
# ------------------------------------
#
#
#
# ### 3. 🔄 Control Flow
#
# 3.1 ⚖️ Conditional Statements
# - 🧑‍⚖️ if, elif, else conditions
# - 🏛️ Nested conditions
# - ⏩ Ternary Operator (Conditional Expressions)
#
# 3.2 🔁 Loops
# - 🔄 for Loop: Iterating through lists, tuples, strings, sets, dictionaries
# - 🔁 while Loop: Repeated execution based on condition
# - 🛑 Loop Control: break, continue, pass
#
#
# ------------------------------------
#
#
#
# ### 4. 🔣 Functions
#
# 4.1 📝 Basic Functions
# - 🧑‍💻 Defining and calling functions
# - 🧩 Parameters and return values
# - 🗂️ Default Arguments
# - 🗝️ Keyword Arguments
# - 🌀 Variable-length Arguments (*args, **kwargs)
#
# 4.2 🚀 Advanced Functions
# - 🪄 Lambda Functions
# - 🔁 Recursion
# - 🏠 Function Closure (Nested functions)
#
#
# ------------------------------------
#
#
#
# ### 5. 🏛️ Object-Oriented Programming (OOP)
#
# 5.1 🧑‍💻 OOP Basics
# - 🏗️ Classes & Objects
# - ⚙️ Methods: Instance, Class, Static
# - 🏠 Constructors (__init__)
#
# 5.2 🧙 OOP Advanced Topics
# - 🪜 Inheritance
# - 🎭 Polymorphism (Method Overriding & Overloading)
# - 🔒 Encapsulation (Private, Protected Variables, Getters, Setters)
# - 🧑‍💼 Abstraction (Abstract Classes, Methods)
# - 🪄 Magic Methods (__str__(), __repr__(), __add__(), etc.)
#
#
# ------------------------------------
#
#
#  ### 6. 🌐 Advanced Python Concepts
#
# 6.1 ⚙️ Generators & Iterators
# - 🔄 Iterators (__iter__(), __next__())
# - ⛏️ Generators (yield)
# - 🌀 Generator Expressions
# - 🧠 Lazy Evaluation
#
# 6.2 🪄 Decorators
# - 🛠️ Function Decorators
# - 🏛️ Class Decorators
#
# 6.3 🏠 Context Managers
# - 🔄 with Statement
# - 🏗️ Creating Custom Context Managers (__enter__(), __exit__())
#
# 6.4 ⚡ Multithreading & Multiprocessing
# - 🔄 Threading Module
# - 🧠 Multiprocessing Module
#
# 6.5 🗂️ File Handling
# - 📖 Opening, Reading, Writing Files
# - 📄 File Modes: r, w, a, rb, wb
# - 🏠 Using Context Managers
#
#
# ------------------------------------
#
#
#
#  ### 7. 📚 Python Libraries & Frameworks
#
# - 📊 NumPy: Arrays, Math Operations
# - 🧮 Pandas: DataFrames, Data Manipulation
# - 📈 Matplotlib: Data Visualization
# - 📉 Seaborn: Statistical Visualization
# - 🌐 Requests: HTTP Requests
# - 🕸️ BeautifulSoup: Web Scraping
# - 🏛️ Django/Flask: Web Development
#
#
# ------------------------------------
#
#
#
# ### 8. 🧠 Other Advanced Topics
#
# 8.1 🔍 Regular Expressions
# - 🧑‍💻 Pattern Matching (re Module)
#
# 8.2 ⚠️ Error Handling
# - 🧑‍⚖️ try, except, finally, else
# - 🚨 Custom Exceptions
#
# 8.3 🧪 Unit Testing
# - 🧑‍🔬 unittest Framework
#
# 8.4 🧹 Memory Management
# - 🗑️ Garbage Collection
# - 🧠 Memory Optimization
#
#
#
# ------------------------------------
#
#
#
# ### 9. 🧩 Python Design Patterns
#
# - 🏠 Singleton
# - 🏭 Factory
# - 📣 Observer
# - 🧠 Strategy
# - 📜 Command
